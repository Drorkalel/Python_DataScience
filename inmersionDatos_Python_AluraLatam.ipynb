# %% [markdown]
# <a href="https://colab.research.google.com/github/Drorkalel/inmersionDatos_python/blob/main/inmersionDatos_Python_AluraLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AULA 1 y 2**
#  Iniciamos nuestra segunda inmersion de datos "Tratamiento de Datos y Primeros Graficos"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/inmuebles_bogota.csv')

inmuebles.head() #Se muestran los primeros 5 registro del dataset
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns = columnas)

# %% [markdown]
# * se muestran 9520 filas y 8 columnas del dataset

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# * Muestra el nombre de las columnas y el tipo de dato string

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# * Se cambian caracteres especiales como ñs y comas para que no presenten problemas al realizar el analisis

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 458   Apartamento        Apartamento en venta en Kennedy             3      2
# 869   Apartamento       Apartamento en venta en Santa Fe             3      2
# 4035  Apartamento      Apartamento en venta en Chapinero             2      3
# 3830         Casa    Casa en venta en Zona Noroccidental             4      3
# 2511  Apartamento  Apartamento en venta en Puente Aranda             2      2
# 4834  Apartamento        Apartamento en venta en Usaquén             2      1
# 2606  Apartamento    Apartamento en venta en Los Rosales             3      3
# 2850  Apartamento           Apartamento en venta en Bosa             3      1
# 1489  Apartamento           Apartamento en venta en Bosa             3      1
# 2884         Casa                  Casa en venta en Bosa             3      1
#
#       Area              Barrio  \
# 458     87             Kennedy
# 869     69            Santa Fe
# ...

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                  Descripcion  Habitaciones  \
# 254   Apartamento             Apartamento en venta en Cedritos             3
# 4547  Apartamento             Apartamento en venta en El Chicó             3
# 9364         Casa                     Casa en venta en Kennedy             3
# 3780  Apartamento              Apartamento en venta en Mazuren             3
# 1784  Apartamento   Apartamento en venta en Zona Noroccidental             3
# 5903  Apartamento        Apartamento en venta en Santa Barbara             3
# 8788  Apartamento          Apartamento en venta en Bella Suiza             2
# 3794  Apartamento   Apartamento en venta en Zona Noroccidental             3
# 5599  Apartamento  Apartamento en venta en Nicolas De Federman             2
# 5513  Apartamento       Apartamento en venta en Barrios Unidos             3
#
#       Banos  Area               Barrio                                    UPZ  \
# ...

# %% [markdown]
# * Muestra la informacion del  dataset

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# * Permite ubicar un registro especifico del data frame, en realidad seria el registro 301 porque empieza desde cero

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Baños  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Área       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# * Muestra que el campo no se creo como un entero, sino como una cadena de texto

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# * Muestra el registro de la columna valor del registro 300

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %% [markdown]
# * Muestra la descripcion e informacion del registro 300

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Baños                                         1
# Área                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# * Calcula la media del Area de todos los inmuebles registrados

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# * Muestra los barrios que estan en Chico Reservado bajo el valor de true

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# * Aplica un filtro, sumando todos los valores true

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %% [markdown]
# * Se crea un nuevo data frame con la variable inmuebles_chico

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %% [markdown]
# * Muestra todos los registros que se encuentran en chico reservado

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %% [markdown]
# * Aplica un filtro sumando todoos los valores true de chico reservado

# %%
sum(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 225

# %% [markdown]
# * Se calcula la media del Area de los inmuebles de chico reservado y es menor que el promedio en general

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# * Muestra la cantidad de barrios que hay en el dataset

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# * Muestra la cantidad de viviendass por barrios

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# * Muestra el total de viviendas por Unidad de Planeacion Zonal

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %% [markdown]
# * Muestra el total de los barrios en un grafico de barras

# %%
inmuebles_Barrio = inmuebles.Barrio.value_counts()
inmuebles_Barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_Barrio.head(10).plot.bar() #Muestra el top 10 de los barrios con mas inmuebles para venta
# Out:
# <Axes: >

# %%
inmuebles.head(10).Barrio #Top 10 en tabla
# Out:
# 0    Zona Noroccidental
# 1              Castilla
# 2       Chico Reservado
# 3               Usaquén
# 4           Bella Suiza
# 5           Bella Suiza
# 6           Bella Suiza
# 7           Bella Suiza
# 8              El Chicó
# 9           Bella Suiza
# Name: Barrio, dtype: object

# %%
inmuebles_Barrio.head(20).plot.bar() #Top 20 de inmuebles por barrio
# Out:
# <Axes: >

# %%
inmuebles.describe() #Se visualizan datos estadisticos como media, desviacion estandas, cuartiles, mediana, valor min, valor max
# Out:
#        Habitaciones   Banos      Area
# count       9520.00 9520.00   9520.00
# mean           3.07    2.45    146.66
# std            2.05    1.26   1731.38
# min            1.00    0.00      2.00
# 25%            2.00    2.00     57.00
# 50%            3.00    2.00     80.00
# 75%            3.00    3.00    135.00
# max          110.00    9.00 166243.00

# %% [markdown]
# * Se visualiza que se genera un resultado diferente al esperado debido a que es cadena de texto, hace una concatenacion.

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] + inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# * la funcion split separa las variables del dato, se aplica tratamientos de String a los datos

# %%
inmuebles.Valor[0].split() #el split separa el valor del simbolo pesos del valor numerico
# Out:
# ['$', '360.000.000']

# %% [markdown]
# * Convierte el campo Valor en un dataset de string de oan

# %%
valor = inmuebles.Valor.str.split(expand=True)# expand=True organiza en 2 columnas el dataframe, mientras con solo split queda en una sola columna
inmuebles['Moneda'] = valor[0] #se crea la variable valor y se toma la primera columna y se le da el valor Moneda
inmuebles['Precio'] = valor[1] #se toma la segunda columna de la variable valor y se le da el valor precio
inmuebles.sample(3) # se toma un ejemplo de solo 3 registros aleatorios
# Out:
#              Tipo                      Descripcion  Habitaciones  Banos  Area  \
# 779   Apartamento  Apartamento en venta en Usaquén             1      2    54
# 6791  Apartamento     Apartamento en venta en Bosa             3      1    47
# 6747         Casa     Casa en venta en Teusaquillo             6      6   319
#
#            Barrio           UPZ            Valor Moneda         Precio
# 779       Usaquén       Usaquén    $ 400.000.000      $    400.000.000
# 6791         Bosa  Bosa Central    $ 130.000.000      $    130.000.000
# 6747  Teusaquillo   Teusaquillo  $ 1.100.000.000      $  1.100.000.000

# %%
inmuebles.info() # Las columnas de moneda y precio se toman como cadena de texto en el dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'].sum() #Por ser cadenas de textos no se ejecuta la suma, mas bien lo concatena
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True) #Se reeplaza el punto del String por espacio en blanco y el atributo regex que haceel reemplazo

# %%
inmuebles[['Precio','Barrio']] #Se colocan los dos valores dentro de corchete para que se interprete como un dataset, se ve sin puntos
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info() # En esta instancia el dataset se sigue mostrando como objetos y no numeros
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000 # Se crea una nueva columna con un dato flotante que reemplaza al dato String
inmuebles.info()                                                      # Es una manera de convertir series de datos a series de numeros
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe() #Se visualizan datos como conte, media, desviacion standar, primer cuartil, mediano o segundo cuartil
                    # tercer cuartil, y el valor maximo
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2) # aplicacion que reduce cantidad de decimales a solo dos
pd.set_option('display.float_format', lambda x: '%.2f' % x) # se usa un atributo lambda para aplicacion rapida, con un formato de decimal float
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110] #Se realiza una busqueda de un inmueble con 110 habitaciones con el metodo .loc, pero se ve que al
                                              #parecer hubo un error en la digitacion porque es un inmueble de 110 metros cuadrados
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2] #Se efectua busqueda de un inmueble con un area de 2 metros cuadrados y se observa un error al ingresar datos
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100) # entre mas bins hay mas claridad en la distribucion del grafico de histograma
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt #Libreria de python para mejorar grafico
import seaborn as sns #Libreria de python basada en matplotlib de alta calidad 

plt.figure(figsize=(10,6)) # lienzo sobre el que se va a graficar
grafica=sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo') # Se crea la variable grafica para agregar el titulo en siguiente sentencia,
                                                                                #'kde, es la curva de densidad', hue añade otra dimension de grafico
grafica.set_title('Distribucion de los Valores de los Inmuebles en Bogota')
plt.xlim((50,1000)) #con base en los datos del precio minimo y maximo de la sentencia 'describe' se coloca el rango para mejorar histograma
#plt.ylim((0,20)) # Se coloca un limite entre 0 y 100 mil inmuebles se usa este comando para reducir el rango y poder ver los inmuebles de menos cantidad
plt.savefig('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/Imagenes/Valor_inmuebles.png',format='png')
plt.show() #Sentencia para graficar el histograma

# %% [markdown]
# *Desafios*
# 1. Estudiar mejor el histograma comparando 3 tipos de inmuebles (Refinar el grafico, titulos, fuentes,colores, conclusion de informacion)
#
# 2. precio del metro cuadrado por barrio y hacer el grafico mas adecuado para esta nueva variable

# %% [markdown]
# # inmersionDatos_aula3

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3) #Se colocan solo 3 primeras filas para que muestre la columna nueva
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %%
inmuebles.groupby('Barrio').mean() #Se agrupan los inmuebles por 149 barrios y se calcula la media
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum() #Se suman los atributos de la agrupacion de barrios
datos_barrio #Se ejecuta para visualizacion de datos
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area'] # Se calcula el m2
# del barrio y se obtiene el valor dem m2 del Barrio
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio']) #Se crea diccionario donde se promedia el metro cuadrado
#del barrio y se compara con el valor del metro cuadrado general

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index #muestra los 10 primeros barrios con mas inmuebles de venta

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios') # Se hace una consulta de los top mas vendidos
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,6))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data=datos_barrio.query('Barrio in @top_barrios'))
# Se grafica en seaborn el top 10 de los barrios mas vendidos
ax.tick_params(axis='x', rotation=45) #Parametro de mejora de visualizacion de labels

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))

ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15')) #se añade una condicion que
#Permita reducir los valores outliers(valores atipicos) en el grafico de caja
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500')) #Se agrega condicion de Area para mejorar grafico
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query("Barrio in @top_barrios & Precio_Millon < 2000"))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Identificación (Capítulo A).csv', sep = ';', encoding='Latin-1')# se
datos_raw.head() #Soluciona el error de utf-8 con encoding y se organiza la dataset con el atributo sep
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape # sentencia muestra la cantidad de registros 106467
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';', encoding = 'Latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'Latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'Latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Educación (Capitulo H).csv', sep = ';', encoding = 'Latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';', encoding = 'Latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Fuerza de trabajo (Capítulo K).csv', sep = ';', encoding = 'Latin-1')
# Out:
# <ipython-input-42-7b255477b08f>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'Latin-1')
# <ipython-input-42-7b255477b08f>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'Latin-1')
# <ipython-input-42-7b255477b08f>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/Educación (Capitulo H).csv', sep = ';', encoding = 'Latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw, datos_b, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-45-31131df05887>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# **Desafio**
# 1. Estudiar la parte conceptual de la base de datos del DANE, entender las variables.
#
# 2. Ordenar mejor el notebook para que el proyecto quede mejor presentado

# %% [markdown]
# #inmersionDatos_aula 4

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane) #se renombran las columnas con el diccionario dane cargado
datos_dane.columns #Se muestra el nuevo indice de columnas
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Al dataset datos_dane se agrupa por columnas seleccionadas y se promedia y se muestran los 5 principales
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos   #se crea una variable llamada datos que es igual a datos_dane, que se visualiza en pantalla y se convierten a binarios donde 1 es 'si' y 0 es 'no'
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados    #se crea un dataset llamado 'datos_tratados' con la agrupacion de datos y luego se promedia para luego visualizar en cuadro de datos
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles, datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles, datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valor_m2_Millon           9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %%
upz = pd.read_csv('/content/drive/MyDrive/INMERSION_DATOS_PYTHON/datos_bogota/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valor_m2_Millon           9318 non-null   float64
#  12  Valor_m2_Barrio           9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=datos_ml, y='Precio_Millon') #Se hace grafico en seaborns del dataset 'datos_ml'
plt.show()

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60') #Se hace una consulta que estan alejados y son outliers para sacarlos del dataset
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')#Se usa la aplicacion query para hacer un filtro donde se concentra la mayoria de precios
datos_ml                                              # y se da un nuevo valor a la variable 'datos_ml', se reduce el dataset a 9277 registros
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=datos_ml, y='Precio_Millon') #Se realiza grafico con los nuevos parametros quitando outliers
plt.show()

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI', y='Valor_m2_Millon') 
plt.ylim((0,15))
plt.show()

# %%
datos_ml.corr().head(10) #En el cuadro de correlacion entre valor_m2_millon y salario_anual_mi se ve que hay una correlacion directa por ser igual a 1
            #Cuando la correlacion es negativa es una correlacion inversa y cuando es igual a cero, indica que no hay correlacion
# Out:
#                   Habitaciones  Banos  Area  Precio_Millon  Valor_m2_Millon  \
# Habitaciones              1.00   0.44  0.03           0.18            -0.31
# Banos                     0.44   1.00  0.04           0.66            -0.03
# Area                      0.03   0.04  1.00           0.04            -0.04
# Precio_Millon             0.18   0.66  0.04           1.00             0.36
# Valor_m2_Millon          -0.31  -0.03 -0.04           0.36             1.00
# Valor_m2_Barrio          -0.21   0.13 -0.04           0.40             0.49
# CONJUNTO_CERRADO         -0.12   0.16 -0.01           0.32             0.33
# INSEGURIDAD               0.13  -0.19 -0.00          -0.37            -0.37
# TERMINALES_BUS            0.08  -0.17 -0.01          -0.28            -0.29
# BARES_DISCO               0.11  -0.12 -0.01          -0.23            -0.22
#
#                   Valor_m2_Barrio  CONJUNTO_CERRADO  INSEGURIDAD  \
# Habitaciones                -0.21             -0.12         0.13
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16); #Grafico de calor que muestra matriz de correlacion entre variables

# %%
from re import X
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)#se establecen variables de entrenamiento con un 75% del tamaño de datos
                                                        # y una aleatoriedad cada 99 datos

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
y_test
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Precio_Millon, Length: 2079, dtype: float64

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train,y_train) #Se ajusta modelo de entrenamiento y de prueba, queda listo modelo para pedecir
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
#baseline_mae
baseline_r2 = r2_score(y_test, y_predict_test) #En esta instancia el modelo no es eficiente ni en mean ni en r2
print(baseline_mae, baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)     #Se agregan 2 variables adicionales, y el modelo mejora en cuanto al modelo de prueba y aprendizaje
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])
